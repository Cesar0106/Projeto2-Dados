# %% [markdown]
# ## Projeto 2 - Ciência dos Dados
#
# **Feito por:**
#
# Cesar Ades
#
# Diogo Duarte
#
# Jonathan Sutton
#
# Joras Oliveira

# %% [markdown]
# ## Introdução
#
# Para o Projeto 2 da disciplina de Ciência dos Dados, decidimos trabalhar com um target qualitativo, que classificaria se a música seria um “hit” ou não, com o critério de ela ter aparecido na lista semanal top 100 da empresa Billboard entre os anos de 2010 até 2019. Para chegar ao resultado final, utilizaremos um classificador com uma base de dados de aproximadamente 6400 músicas.

# %% [markdown]
# **Importando as bibliotecas a serem utilizadas**

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sn
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **Começando a leitura e manipulação dos dados**

# %%
import chardet
with open('dataset-of-10s.csv', 'rb') as rawdata: # Abre o dataset
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
dados = pd.read_csv('dataset-of-10s.csv',encoding='utf-8') # Faz a leitura do Dataset.

del dados['uri'] # Coluna de identificação de músicas do Spotify removida, pois são valores únicos que não influenciam no trabalho.

dados.head(50) # Imprime as primeiros 50 músicas do Dataset.
# Out:
#                                                 track  \
# 0                                         Wild Things
# 1                                           Surfboard
# 2                                        Love Someone
# 3                 Music To My Ears (feat. Tory Lanez)
# 4                       Juju On That Beat (TZ Anthem)
# 5                          Here's To Never Growing Up
# 6                                    Sex Metal Barbie
# 7                                       Helluva Night
# 8                                     Holiday With HH
# 9                                             My Last
# 10                                Break Up In The End
# 11                                             Cirrus
# 12                              Theme From "Bus Stop"
# 13                               Crawling Back To You
# 14  Maze of Martyr (Official Dominator 2017 anthem...
# 15                                      Hotline Bling
# 16                                        Cut Her Off
# 17                                   Beautiful People
# 18                                           Survival
# 19                  Squidwards Nose (feat. Kg Prince)
# 20                                         Windshield
# 21                         Don't Speak (Instrumental)
# 22                                             Faster
# 23                                              Sugar
# 24                                             Badges
# 25                                 Art House Director
# 26                                       10.000 Falls
# 27                                The Healing Process
# 28                                     Love Don't Run
# 29                                            Lockjaw
# 30                                  Sleep Hibernation
# 31                       You Should See Me In A Crown
# 32                                        Swish Swish
# 33                                         Hot Tottie
# 34                                          New Salem
# 35                                   Raise Your Glass
# 36                                  Mr. Misunderstood
# 37                                              Rolex
# 38                                          Worldless
# 39                                  B**** I'm Madonna
# 40                         Ride 4 Me (feat. PnB Rock)
# 41                                        Death Grips
# 42                            Baby Swing - Radio Edit
# 43                                       Good Feeling
# 44                              You Need To Calm Down
# 45                                              Money
# 46                                Wolf Finder General
# 47                                    Butterfly Doors
# 48                                           Somebody
# 49                                          Don't Cry
#
#                                     artist  danceability  energy  key  \
# 0                             Alessia Cara         0.741  0.6260    1
# 1                                Esquivel!         0.447  0.2470    5
# 2                             Lukas Graham         0.550  0.4150    9
# 3                            Keys N Krates         0.502  0.6480    0
# 4           Zay Hilfigerrr & Zayion McCall         0.807  0.8870    1
# 5                            Avril Lavigne         0.482  0.8730    0
# 6                           In This Moment         0.533  0.9350    0
# 7                                 Ludacris         0.736  0.5220    2
# 8                                  No Bros         0.166  0.9850    7
# 9           Big Sean Featuring Chris Brown         0.387  0.7730    8
# 10                           Cole Swindell         0.507  0.3720    1
# 11                                  Bonobo         0.640  0.8440    2
# 26   0.2090  180.033       241583               4    62.60494        12
# 27   0.0643  135.859       161442               1    22.19678        11
# 28   0.2560  147.473       219267               4    33.96792         9
# 29   0.2600  169.912       223147               4    59.76709         9
# 30   0.0708   72.917       175132               4    55.05616         7
# 31   0.3230  150.455       180953               4    27.06075         9
# 32   0.5750  119.954       242520               4    25.02456        11
# 33   0.6690   87.525       299333               4    22.25047        15
# 34   0.2610  104.676       203960               4    29.48355        11
# 35   0.6250  122.019       202960               4    23.80940         8
# 36   0.5460  129.220       319240               4    32.15759         8
# 37   0.7890  144.946       238587               4    27.10088        13
# 38   0.4240   90.038       205320               4    32.36458         8
# 39   0.5530  149.999       228853               4    39.10846        11
# 40   0.7210   94.991       189467               4    41.38748         6
# 41   0.2300   74.541       226086               4    71.18209         8
# 42   0.8280  121.930       190143               4    33.27024         6
# 43   0.6840  128.011       248133               4    36.04713         8
# 44   0.7140   85.026       171360               4    25.16103         9
# 45   0.4710  108.002       331676               4    58.93916        13
# 46   0.1720  135.497       165449               4    57.54756         6
# 47   0.4290  130.008       132923               4    51.23142         6
# 48   0.7350  104.990       189907               4    19.54918         8
# 49   0.2100  111.913       249450               4    86.81431         8
#
#     target
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# 5        1
# 6        0
# 7        1
# 8        0
# 9        1
# 10       1
# 11       0
# 12       0
# 13       1
# 14       0
# 15       1
# 16       1
# 17       1
# 18       1
# 19       0
# 20       0
# 21       0
# 22       1
# 23       1
# 24       0
# 25       0
# 26       0
# 27       0
# 28       1
# 29       1
# 30       0
# 31       1
# 32       1
# 33       1
# 34       0
# 35       1
# 36       1
# 37       1
# 38       0
# 39       1
# 40       0
# 41       0
# 42       0
# 43       1
# 44       1
# 45       0
# 46       0
# 47       1
# 48       1
# 49       1

# %%
#Quantidade de Musicas
index = dados. index
number_of_rows = len(index)
print(f'Este Dataset tem:  {number_of_rows}' )

dados.shape #numero de linhas e colunas
# Out:
# Este Dataset tem:  6398
# (6398, 18)

# %%
dados.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   6398.000000  6398.000000  6398.000000  6398.000000  6398.000000
# mean       0.568163     0.667756     5.283526    -7.589796     0.645514
# std        0.191103     0.240721     3.606216     5.234592     0.478395
# min        0.062200     0.000251     0.000000   -46.655000     0.000000
# 25%        0.447000     0.533000     2.000000    -8.425000     0.000000
# 50%        0.588000     0.712500     5.000000    -6.096500     1.000000
# 75%        0.710000     0.857000     8.000000    -4.601250     1.000000
# max        0.981000     0.999000    11.000000    -0.149000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  6398.000000   6398.000000       6398.000000  6398.000000  6398.000000
# mean      0.098018      0.216928          0.165293     0.196700     0.443734
# std       0.097224      0.296835          0.318736     0.166148     0.245776
# min       0.022500      0.000000          0.000000     0.016700     0.000000
# 25%       0.038825      0.008533          0.000000     0.096800     0.240000
# 50%       0.057200      0.067050          0.000017     0.126000     0.434000
# 75%       0.112000      0.311000          0.057650     0.249000     0.628000
# max       0.956000      0.996000          0.995000     0.982000     0.976000
#
#              tempo   duration_ms  time_signature   chorus_hit     sections  \
# count  6398.000000  6.398000e+03     6398.000000  6398.000000  6398.000000
# mean    122.353871  2.367042e+05        3.930916    41.028399    10.316505
# std      29.847389  8.563698e+04        0.377469    19.568827     3.776011
# min      39.369000  2.985300e+04        0.000000     0.000000     2.000000
# 25%      98.091250  1.932068e+05        4.000000    28.059135     8.000000
# 50%     121.070000  2.212465e+05        4.000000    36.265365    10.000000
# 75%     141.085000  2.593165e+05        4.000000    48.292538    12.000000
# max     210.977000  1.734201e+06        5.000000   213.154990    88.000000
#
#             target
# count  6398.000000
# mean      0.500000
# std       0.500039
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %%
print(dados.target.value_counts(True))
print(dados.dtypes)
# Out:
# 1    0.5
# 0    0.5
# Name: target, dtype: float64
# track                object
# artist               object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# chorus_hit          float64
# sections              int64
# target                int64
# dtype: object

# %%
#todos os hits

hit = dados.loc[dados["target"] == 1, :]
hit
# Out:
#                               track                          artist  \
# 0                       Wild Things                    Alessia Cara
# 2                      Love Someone                    Lukas Graham
# 4     Juju On That Beat (TZ Anthem)  Zay Hilfigerrr & Zayion McCall
# 5        Here's To Never Growing Up                   Avril Lavigne
# 7                     Helluva Night                        Ludacris
# ...                             ...                             ...
# 6390               Tear In My Heart               twenty one pilots
# 6391                Sweater Weather               The Neighbourhood
# 6392                    Untouchable      YoungBoy Never Broke Again
# 6394              Calling My Spirit                     Kodak Black
# 6395                  Teenage Dream                      Katy Perry
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.741   0.626    1    -4.826     0       0.0886       0.02000
# 2            0.550   0.415    9    -6.557     0       0.0520       0.16100
# 4            0.807   0.887    1    -3.892     1       0.2750       0.00381
# 5            0.482   0.873    0    -3.145     1       0.0853       0.01110
# 7            0.736   0.522    2    -8.020     1       0.1160       0.02990
# ...            ...     ...  ...       ...   ...          ...           ...
# 6390         0.655   0.632    2    -4.802     1       0.0489       0.01890
# 6391         0.612   0.807   10    -2.810     1       0.0336       0.04950
# 6392         0.780   0.784    1    -5.039     1       0.1860       0.04470
# 6394         0.910   0.366    1    -9.954     1       0.0941       0.09960
# 6395         0.719   0.804   10    -4.581     1       0.0355       0.01320
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.0828    0.706  108.029       188493
# 2             0.000000    0.1080    0.274  172.065       205463
# 4             0.000000    0.3910    0.780  160.517       144244
# 5             0.000000    0.4090    0.737  165.084       214320
# 7             0.000000    0.1080    0.369   97.547       200387
# ...                ...       ...      ...      ...          ...
# 6390          0.000000    0.0722    0.447  120.113       188493
# 6391          0.017700    0.1010    0.398  124.053       240400
# 6392          0.000000    0.1220    0.430   85.023       180706
# 6394          0.000000    0.2610    0.740  119.985       152000
# 6395          0.000003    0.1390    0.605  119.999       227760
#
#       time_signature  chorus_hit  sections  target
# 0                  4    41.18681        10       1
# 2                  4    44.89147         9       1
# 4                  4    24.99199         8       1
# 5                  4    32.17301        12       1
# 7                  4    60.21027        10       1
# ...              ...         ...       ...     ...
# 6390               4    51.52804         8       1
# 6391               4    91.20552         7       1
# 6392               4    46.62277         8       1
# 6394               4    32.53856         8       1
# 6395               4    20.73371         7       1
#
# [3199 rows x 18 columns]

# %%
#todos os nao hits
not_hit = dados.loc[dados["target"] == False, :]
not_hit
# Out:
#                                     track          artist  danceability  \
# 1                               Surfboard       Esquivel!         0.447
# 3     Music To My Ears (feat. Tory Lanez)   Keys N Krates         0.502
# 6                        Sex Metal Barbie  In This Moment         0.533
# 8                         Holiday With HH         No Bros         0.166
# 11                                 Cirrus          Bonobo         0.640
# ...                                   ...             ...           ...
# 6384         Gimme D' Road - Carnival Mix    Calypso Rose         0.395
# 6386                         Vast Changes        Regentum         0.396
# 6393                        Lotus Flowers           Yolta         0.172
# 6396                       Stormy Weather  Oscar Peterson         0.600
# 6397                                 Dust     Hans Zimmer         0.121
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 1      0.247    5   -14.661     0       0.0346       0.87100
# 3      0.648    0    -5.698     0       0.0527       0.00513
# 6      0.935    0    -3.704     1       0.1280       0.01390
# 8      0.985    7    -2.886     1       0.1700       0.00183
# 11     0.844    2    -8.412     0       0.0374       0.39500
# ...      ...  ...       ...   ...          ...           ...
# 6384   0.927    4    -4.418     1       0.1650       0.11600
# 6386   0.044    9   -25.088     0       0.0370       0.98400
# 6393   0.358    9   -14.430     1       0.0342       0.88600
# 6396   0.177    7   -16.070     1       0.0561       0.98900
# 6397   0.123    4   -23.025     0       0.0443       0.96400
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 1               0.8140    0.0946   0.2500  155.489       176880
# 3               0.0000    0.2040   0.2910   91.837       193043
# 6               0.0000    0.1680   0.4810  140.092       262493
# 8               0.0142    0.9580   0.1390  174.725       252787
# 11              0.9330    0.0827   0.3640  119.042       352247
# ...                ...       ...      ...      ...          ...
# 6384            0.0000    0.4410   0.9410  188.384       191905
# 6386            0.9470    0.0802   0.0898   71.200       224636
# 6393            0.9660    0.3140   0.0361   72.272       150857
# 6396            0.8680    0.1490   0.5600  120.030       213387
# 6397            0.6960    0.1030   0.0297   95.182       341396
#
#       time_signature  chorus_hit  sections  target
# 1                  3    33.18083         9       0
# 3                  4    29.52521         7       0
# 6                  4    21.04510        14       0
# 8                  4    31.23583        11       0
# 11                 4    80.60317        13       0
# ...              ...         ...       ...     ...
# 6384               3    68.27089         8       0
# 6386               5    15.34214        12       0
# 6393               4    24.30824         7       0
# 6396               4    21.65301        14       0
# 6397               4    71.05343        15       0
#
# [3199 rows x 18 columns]

# %% [markdown]
# **Análise explorátoria inicial**

# %%
# Plotando gráficos que relacionam cada classificação com a feature

sns.pairplot(
    dados,
    x_vars = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',  'instrumentalness',  'liveness',  'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit', 'sections'],
    y_vars = ['target'],
    height = 12,
)

# %% [markdown]
# **Análise** : jdbiu
# wbdiqujwbd
# ùoiqgdiv
# qdb eo 87qb
# w d8pewf7

# %% [markdown]
# **Começando a desenvolver Regressão Linear**

# %%
# Definindo o grupo de variáveis independentes
X = dados[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',  'instrumentalness',  'liveness',  'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit', 'sections']]

# Definindo o grupo de variáveis dependentes
y = dados[['target']]

# Montando o teste e treinamento
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
# Aplicando a lógica da Regressão Linear

logistic_regression= LogisticRegression()
logistic_regression.fit(X_train,y_train)
y_pred=logistic_regression.predict(X_test)
# Out:
# /Users/Diogo/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Diogo/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Montando a matriz de confusão

lista = list(y_test['target'])

plt.figure(figsize=(8,8))

cf_matrix = confusion_matrix(lista, y_pred)


group_names = ['True Negative','False Positive','False Negative','True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)



sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues', )
plt.ylim(2, 0.01)



plt.show()

# %% [markdown]
# **Explicando o gráfico acima:**
#     O gráfico mostra

# %%
# Mostrando a acúracia do nosso classificador

print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
plt.show()
# Out:
# Accuracy:  0.644375
